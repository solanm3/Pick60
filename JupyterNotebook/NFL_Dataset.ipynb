# %%
import pandas

# %%
import numpy

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b666bf274d0a> in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df = pandas.read_csv('nfl_dataset_2002-2019week6.csv')

# %%
df.head()
# Out:
#          date      away     home  first_downs_away  first_downs_home  \
# 0  2002-09-05     49ers   Giants                13                21
# 1  2002-09-08      Jets    Bills                18                26
# 2  2002-09-08   Vikings    Bears                19                20
# 3  2002-09-08  Chargers  Bengals                27                13
# 4  2002-09-08    Chiefs   Browns                24                24
#
#   third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0             4-12             9-16               0-0               0-1
# 1              2-8             7-17               0-0               2-2
# 2             5-13             7-13               0-0               0-0
# 3             6-10             4-11               0-0               0-0
# 4             5-11             4-11               0-0               0-0
#
#    passing_yards_away  ...  redzone_away  redzone_home  drives_away  \
# 0                 166  ...           0-8           0-6           13
# 1                 193  ...           0-9           0-8           17
# 2                 228  ...           0-7           0-6           17
# 3                 160  ...           0-7           0-5           11
# 4                 276  ...          0-10          0-10           20
#
#    drives_home  def_st_td_away def_st_td_home possession_away possession_home  \
# 0           15               0              0           27:32           32:28
# 1           18               2              0           21:06           39:08
# 2           17               0              0           31:31           28:29
# 3           15               0              0           37:48           22:12
# 4           17               0              0           30:16           29:44
#
#   score_away  score_home
# 0         16          13
# 1         37          31
# 2         23          27
# 3         34           6
# 4         40          39
#
# [5 rows x 39 columns]

# %%
to_drop = ['fumbles_home', 'fumbles_away', 'int_away', 'int_home', 'drives_away', 'drives_home']

# %%
import pandas as pd

# %%
import numpty as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-b1ce91a29230> in <module>
# ----> 1 import numpty as np
#
# ModuleNotFoundError: No module named 'numpty'

# %%
import numpy as np

# %%
df.dropna(inplace = True)

# %%
new = df['comp_att_home'].str.split(' ', n = 1, expand = True)

# %%
new = df['comp_att_home'].str.split('-', n = 1, expand = True)

# %%
df["Home_attempts_completed"] = new[0]

# %%
df["Home_attempts"] = new[1]

# %%
df.drop[columns =['name'], inplace = True]
# Out:
#   File "<ipython-input-16-b150bbc77830>", line 1
#     df.drop[columns =['name'], inplace = True]
#                     ^
# SyntaxError: invalid syntax

# %%
df.drop[columns =['name'], inplace = True]
# Out:
#   File "<ipython-input-17-b150bbc77830>", line 1
#     df.drop[columns =['name'], inplace = True]
#                     ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  drives_away  drives_home  def_st_td_away  \
# 0                    166  ...           13           15               0
# 1                    193  ...           17           18               2
# 2                    228  ...           17           17               0
# 3                    160  ...           11           15               0
# 4                    276  ...           20           17               0
# ...                  ...  ...          ...          ...             ...
# 4623                 341  ...           10           10               0
# 4624                 165  ...           14           14               0
# 4625                 270  ...           10           10               0
# 4626                 132  ...           10           10               2
# 4627                 243  ...           11           10               0
#
#       def_st_td_home  possession_away possession_home score_away score_home  \
# 0                  0            27:32           32:28         16         13
# 1                  0            21:06           39:08         37         31
# 2                  0            31:31           28:29         23         27
# 3                  0            37:48           22:12         34          6
# 4                  0            30:16           29:44         40         39
# ...              ...              ...             ...        ...        ...
# 4623               0            32:47           27:13         33         34
# 4624               0            30:14           29:46          0         16
# 4625               0            32:03           27:57         22         24
# 4626               0            34:05           25:55         24         17
# 4627               0            26:56           33:04         22         23
#
#      Home_attempts_completed  Home_attempts
# 0                         28             45
# 1                         26             39
# 2                         20             33
# 3                         18             31
# 4                         28             40
# ...                      ...            ...
# 4623                      27             37
# 4624                      18             28
# 4625                      23             32
# 4626                      26             44
# 4627                      24             39
#
# [4628 rows x 41 columns]

# %%
new = df['comp_att_away'].str.split('-', n = 1, expand = True)

# %%
df["away_attempts_completed"] = new[0]

# %%
df["away_attempts"] = new[1]

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  def_st_td_away  def_st_td_home  \
# 0                    166  ...               0               0
# 1                    193  ...               2               0
# 2                    228  ...               0               0
# 3                    160  ...               0               0
# 4                    276  ...               0               0
# ...                  ...  ...             ...             ...
# 4623                 341  ...               0               0
# 4624                 165  ...               0               0
# 4625                 270  ...               0               0
# 4626                 132  ...               2               0
# 4627                 243  ...               0               0
#
#       possession_away  possession_home  score_away score_home  \
# 0               27:32            32:28          16         13
# 1               21:06            39:08          37         31
# 2               31:31            28:29          23         27
# 3               37:48            22:12          34          6
# 4               30:16            29:44          40         39
# ...               ...              ...         ...        ...
# 4623            32:47            27:13          33         34
# 4624            30:14            29:46           0         16
# 4625            32:03            27:57          22         24
# 4626            34:05            25:55          24         17
# 4627            26:56            33:04          22         23
#
#      Home_attempts_completed Home_attempts away_attempts_completed  \
# 0                         28            45                      16
# 1                         26            39                      24
# 2                         20            33                      16
# 3                         18            31                      15
# 4                         28            40                      20
# ...                      ...           ...                     ...
# 4623                      27            37                      30
# 4624                      18            28                      20
# 4625                      23            32                      28
# 4626                      26            44                      15
# 4627                      24            39                      18
#
#       away_attempts
# 0                26
# 1                30
# 2                28
# 3                19
# 4                29
# ...             ...
# 4623             36
# 4624             34
# 4625             40
# 4626             20
# 4627             32
#
# [4628 rows x 43 columns]

# %%
df['YPPA_away'] = np.where(df['passing_yards_away'] < 1, df['passing_yards_away'], df['passing_yards_away']/df['away_attempts_completed'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-7fe7e11e3b68> in <module>
# ----> 1 df['YPPA_away'] = np.where(df['passing_yards_away'] < 1, df['passing_yards_away'], df['passing_yards_away']/df['away_attempts_completed'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     445         if mask.any():
#     446             with np.errstate(all="ignore"):
# --> 447                 result[mask] = op(xrav[mask], com.values_from_object(yrav[mask]))
#     448
#     449     else:
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-24-f2d1dcf675e9> in <module>
# ----> 1 df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     448
#     449     else:
# --> 450         assert is_scalar(y), type(y)
#     451         assert isinstance(x, np.ndarray), type(x)
#     452         # mask is only meaningful for x
#
# AssertionError: <class 'list'>

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  def_st_td_away  def_st_td_home  \
# 0                    166  ...               0               0
# 1                    193  ...               2               0
# 2                    228  ...               0               0
# 3                    160  ...               0               0
# 4                    276  ...               0               0
# ...                  ...  ...             ...             ...
# 4623                 341  ...               0               0
# 4624                 165  ...               0               0
# 4625                 270  ...               0               0
# 4626                 132  ...               2               0
# 4627                 243  ...               0               0
#
#       possession_away  possession_home  score_away score_home  \
# 0               27:32            32:28          16         13
# 1               21:06            39:08          37         31
# 2               31:31            28:29          23         27
# 3               37:48            22:12          34          6
# 4               30:16            29:44          40         39
# ...               ...              ...         ...        ...
# 4623            32:47            27:13          33         34
# 4624            30:14            29:46           0         16
# 4625            32:03            27:57          22         24
# 4626            34:05            25:55          24         17
# 4627            26:56            33:04          22         23
#
#      Home_attempts_completed Home_attempts away_attempts_completed  \
# 0                         28            45                      16
# 1                         26            39                      24
# 2                         20            33                      16
# 3                         18            31                      15
# 4                         28            40                      20
# ...                      ...           ...                     ...
# 4623                      27            37                      30
# 4624                      18            28                      20
# 4625                      23            32                      28
# 4626                      26            44                      15
# 4627                      24            39                      18
#
#       away_attempts
# 0                26
# 1                30
# 2                28
# 3                19
# 4                29
# ...             ...
# 4623             36
# 4624             34
# 4625             40
# 4626             20
# 4627             32
#
# [4628 rows x 43 columns]

# %%
df['YPPA_away'] = df['passing_yards_away']/['away_attempts'], dtype=np.int64
# Out:
#   File "<ipython-input-27-f6d0e026e304>", line 1
#     df['YPPA_away'] = (df['passing_yards_away']/['away_attempts']), dtype=np.int64
#                      ^
# SyntaxError: can't assign to operator

# %%
df[float('passing_yards_away')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-c815b2df8b2f> in <module>
# ----> 1 df[float('passing_yards_away')]
#
# ValueError: could not convert string to float: 'passing_yards_away'

# %%
df[int('passing_yards_away')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-1606c9d58d6e> in <module>
# ----> 1 df[int('passing_yards_away')]
#
# ValueError: invalid literal for int() with base 10: 'passing_yards_away'

# %%
df['passing_yards_away'] = df['passing_yards_away'].astype(float)

# %%
df['away_attempts'] = df['away_attempts'].astype(float)

# %%
df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-32-f2d1dcf675e9> in <module>
# ----> 1 df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     448
#     449     else:
# --> 450         assert is_scalar(y), type(y)
#     451         assert isinstance(x, np.ndarray), type(x)
#     452         # mask is only meaningful for x
#
# AssertionError: <class 'list'>

# %%
df['YPPA_away'] = (df['passing_yards_away']/['away_attempts'], dtype = np.int64)
# Out:
#   File "<ipython-input-35-4e5c646b5f31>", line 1
#     df['YPPA_away'] = (df['passing_yards_away']/['away_attempts'], dtype = np.int64)
#                                                                          ^
# SyntaxError: invalid syntax

# %%
df['YPPA_away'] = (df['passing_yards_away']/['away_attempts'], dtype = YYPA_away.int64)
# Out:
#   File "<ipython-input-36-7da91d255e3b>", line 1
#     df['YPPA_away'] = (df['passing_yards_away']/['away_attempts'], dtype = YYPA_away.int64)
#                                                                          ^
# SyntaxError: invalid syntax

# %%
print(df.dtypes)
# Out:
# date                        object
# away                        object
# home                        object
# first_downs_away             int64
# first_downs_home             int64
# third_downs_away            object
# third_downs_home            object
# fourth_downs_away           object
# fourth_downs_home           object
# passing_yards_away         float64
# passing_yards_home           int64
# rushing_yards_away           int64
# rushing_yards_home           int64
# total_yards_away             int64
# total_yards_home             int64
# comp_att_away               object
# comp_att_home               object
# sacks_away                  object
# sacks_home                  object
# rushing_attempts_away        int64
# rushing_attempts_home        int64
# fumbles_away                 int64
# fumbles_home                 int64
# int_away                     int64
# int_home                     int64
# turnovers_away               int64
# turnovers_home               int64
# penalties_away              object
# penalties_home              object
# redzone_away                object
# redzone_home                object
# drives_away                  int64
# drives_home                  int64
# def_st_td_away               int64
# def_st_td_home               int64
# possession_away             object
# possession_home             object
# score_away                   int64
# score_home                   int64
# Home_attempts_completed     object
# Home_attempts               object
# away_attempts_completed     object
# away_attempts              float64
# dtype: object

# %%
df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-38-f2d1dcf675e9> in <module>
# ----> 1 df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     448
#     449     else:
# --> 450         assert is_scalar(y), type(y)
#     451         assert isinstance(x, np.ndarray), type(x)
#     452         # mask is only meaningful for x
#
# AssertionError: <class 'list'>

# %%
rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
                              names('rtruediv'), op('/'), truediv=True,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-2d3de87641dc> in <module>
# ----> 1 rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
#       2                               names('rtruediv'), op('/'), truediv=True,)
#
# NameError: name 'arith_method' is not defined

# %%
rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
                              names('rtruediv'), op('/'), truediv=True,
                              fill_zeros=np.inf, default_axis=default_axis,
                              reversed=True),
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-a37b527e1ebf> in <module>
# ----> 1 rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
#       2                               names('rtruediv'), op('/'), truediv=True,
#       3                               fill_zeros=np.inf, default_axis=default_axis,
#       4                               reversed=True),
#
# NameError: name 'arith_method' is not defined

# %%
def _create_methods(arith_method, radd_func, comp_method, bool_method,
                    use_numexpr, special=False, default_axis='columns'):
# Out:
#   File "<ipython-input-42-c4fe62714631>", line 2
#     use_numexpr, special=False, default_axis='columns'):
#                                                         ^
# SyntaxError: unexpected EOF while parsing

# %%
def _create_methods(arith_method, radd_func, comp_method, bool_method,
                    use_numexpr, special=False, default_axis='columns'):
    # creates actual methods based upon arithmetic, comp and bool method
    # constructors.

    # NOTE: Only frame cares about default_axis, specifically: special methods
    # have default axis None, whereas flex methods have default axis 'columns'
    # if we're not using numexpr, then don't pass a str_rep
    if use_numexpr:
        op = lambda x: x
    else:
        op = lambda x: None
    if special:
        def names(x):
            if x[-1] == "_":
                return "__%s_" % x
            else:
                return "__%s__" % x
    else:
        names = lambda x: x

# %%
rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
                              names('rtruediv'), op('/'), truediv=True,
                              fill_zeros=np.inf, default_axis=default_axis,
                              reversed=True),
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-a37b527e1ebf> in <module>
# ----> 1 rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
#       2                               names('rtruediv'), op('/'), truediv=True,
#       3                               fill_zeros=np.inf, default_axis=default_axis,
#       4                               reversed=True),
#
# NameError: name 'arith_method' is not defined

# %%
def _create_methods(arith_method, radd_func, comp_method, bool_method,
                    use_numexpr, special=False, default_axis='columns'):
    # creates actual methods based upon arithmetic, comp and bool method
    # constructors.

    # NOTE: Only frame cares about default_axis, specifically: special methods
    # have default axis None, whereas flex methods have default axis 'columns'
    # if we're not using numexpr, then don't pass a str_rep
    if use_numexpr:
        op = lambda x: x
    else:
        op = lambda x: None
    if special:
        def names(x):
            if x[-1] == "_":
                return "__%s_" % x
            else:
                return "__%s__" % x
    else:
        names = lambda x: x
    radd_func = radd_func or operator.add
    # Inframe, all special methods have default_axis=None, flex methods have
    # default_axis set to the default (columns)
    new_methods = dict(
        add=arith_method(operator.add, names('add'), op('+'),
                         default_axis=default_axis),
        radd=arith_method(radd_func, names('radd'), op('+'),
                          default_axis=default_axis),
        sub=arith_method(operator.sub, names('sub'), op('-'),
                         default_axis=default_axis),
        mul=arith_method(operator.mul, names('mul'), op('*'),
                         default_axis=default_axis),
        truediv=arith_method(operator.truediv, names('truediv'), op('/'),
                             truediv=True, fill_zeros=np.inf,
                             default_axis=default_axis),
        floordiv=arith_method(operator.floordiv, names('floordiv'), op('//'),
                              default_axis=default_axis, fill_zeros=np.inf),
        # Causes a floating point exception in the tests when numexpr
        # enabled, so for now no speedup
        mod=arith_method(operator.mod, names('mod'), None,
                         default_axis=default_axis, fill_zeros=np.nan),
        pow=arith_method(operator.pow, names('pow'), op('**'),
                         default_axis=default_axis),
        # not entirely sure why this is necessary, but previously was included
        # so it's here to maintain compatibility
        rmul=arith_method(operator.mul, names('rmul'), op('*'),
                          default_axis=default_axis, reversed=True),
        rsub=arith_method(lambda x, y: y - x, names('rsub'), op('-'),
                          default_axis=default_axis, reversed=True),
        rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
                              names('rtruediv'), op('/'), truediv=True,
                              fill_zeros=np.inf, default_axis=default_axis,
                              reversed=True),
        rfloordiv=arith_method(lambda x, y: operator.floordiv(y, x),
                               names('rfloordiv'), op('//'),
                               default_axis=default_axis, fill_zeros=np.inf,
                               reversed=True),
        rpow=arith_method(lambda x, y: y ** x, names('rpow'), op('**'),
                          default_axis=default_axis, reversed=True),
        rmod=arith_method(lambda x, y: y % x, names('rmod'), op('%'),
                          default_axis=default_axis, reversed=True),
    )
    new_methods['div'] = new_methods['truediv']
    new_methods['rdiv'] = new_methods['rtruediv']

# %%
def _create_methods(arith_method, radd_func, comp_method, bool_method,
                    use_numexpr, special=False, default_axis='columns'):
    # creates actual methods based upon arithmetic, comp and bool method
    # constructors.

    # NOTE: Only frame cares about default_axis, specifically: special methods
    # have default axis None, whereas flex methods have default axis 'columns'
    # if we're not using numexpr, then don't pass a str_rep
    if use_numexpr:
        op = lambda x: x
    else:
        op = lambda x: None
    if special:
        def names(x):
            if x[-1] == "_":
                return "__%s_" % x
            else:
                return "__%s__" % x
    else:
        names = lambda x: x
    radd_func = radd_func or operator.add
    # Inframe, all special methods have default_axis=None, flex methods have
    # default_axis set to the default (columns)
    new_methods = dict(
        add=arith_method(operator.add, names('add'), op('+'),
                         default_axis=default_axis),
        radd=arith_method(radd_func, names('radd'), op('+'),
                          default_axis=default_axis),
        sub=arith_method(operator.sub, names('sub'), op('-'),
                         default_axis=default_axis),
        mul=arith_method(operator.mul, names('mul'), op('*'),
                         default_axis=default_axis),
        truediv=arith_method(operator.truediv, names('truediv'), op('/'),
                             truediv=True, fill_zeros=np.inf,
                             default_axis=default_axis),
        floordiv=arith_method(operator.floordiv, names('floordiv'), op('//'),
                              default_axis=default_axis, fill_zeros=np.inf),
        # Causes a floating point exception in the tests when numexpr
        # enabled, so for now no speedup
        mod=arith_method(operator.mod, names('mod'), None,
                         default_axis=default_axis, fill_zeros=np.nan),
        pow=arith_method(operator.pow, names('pow'), op('**'),
                         default_axis=default_axis),
        # not entirely sure why this is necessary, but previously was included
        # so it's here to maintain compatibility
        rmul=arith_method(operator.mul, names('rmul'), op('*'),
                          default_axis=default_axis, reversed=True),
        rsub=arith_method(lambda x, y: y - x, names('rsub'), op('-'),
                          default_axis=default_axis, reversed=True),
        rtruediv=arith_method(lambda x, y: operator.truediv(y, x),
                              names('rtruediv'), op('/'), truediv=True,
                              fill_zeros=np.inf, default_axis=default_axis,
                              reversed=True),
        rfloordiv=arith_method(lambda x, y: operator.floordiv(y, x),
                               names('rfloordiv'), op('//'),
                               default_axis=default_axis, fill_zeros=np.inf,
                               reversed=True),
        rpow=arith_method(lambda x, y: y ** x, names('rpow'), op('**'),
                          default_axis=default_axis, reversed=True),
        rmod=arith_method(lambda x, y: y % x, names('rmod'), op('%'),
                          default_axis=default_axis, reversed=True),
    )
    new_methods['div'] = new_methods['truediv']
    new_methods['rdiv'] = new_methods['rtruediv']

    # Comp methods never had a default axis set
    if comp_method:
        new_methods.update(dict(
            eq=comp_method(operator.eq, names('eq'), op('==')),
            ne=comp_method(operator.ne, names('ne'), op('!='), masker=True),
            lt=comp_method(operator.lt, names('lt'), op('<')),
            gt=comp_method(operator.gt, names('gt'), op('>')),
            le=comp_method(operator.le, names('le'), op('<=')),
            ge=comp_method(operator.ge, names('ge'), op('>=')),
        ))
    if bool_method:
        new_methods.update(dict(
            and_=bool_method(operator.and_, names('and_'), op('&')),
            or_=bool_method(operator.or_, names('or_'), op('|')),
            # For some reason ``^`` wasn't used in original.
            xor=bool_method(operator.xor, names('xor'), op('^')),
            rand_=bool_method(lambda x, y: operator.and_(y, x),
                              names('rand_'), op('&')),
            ror_=bool_method(lambda x, y: operator.or_(y, x), names('ror_'), op('|')),
            rxor=bool_method(lambda x, y: operator.xor(y, x), names('rxor'), op('^'))
        ))

    new_methods = dict((names(k), v) for k, v in new_methods.items())
    return new_methods


def add_methods(cls, new_methods, force, select, exclude):
    if select and exclude:
        raise TypeError("May only pass either select or exclude")
    methods = new_methods
    if select:
        select = set(select)
        methods = {}
        for key, method in new_methods.items():
            if key in select:
                methods[key] = method
    if exclude:
        for k in exclude:
            new_methods.pop(k, None)

    for name, method in new_methods.items():
        if force or name not in cls.__dict__:
            bind_method(cls, name, method)

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  def_st_td_away  def_st_td_home  \
# 0                  166.0  ...               0               0
# 1                  193.0  ...               2               0
# 2                  228.0  ...               0               0
# 3                  160.0  ...               0               0
# 4                  276.0  ...               0               0
# ...                  ...  ...             ...             ...
# 4623               341.0  ...               0               0
# 4624               165.0  ...               0               0
# 4625               270.0  ...               0               0
# 4626               132.0  ...               2               0
# 4627               243.0  ...               0               0
#
#       possession_away  possession_home  score_away score_home  \
# 0               27:32            32:28          16         13
# 1               21:06            39:08          37         31
# 2               31:31            28:29          23         27
# 3               37:48            22:12          34          6
# 4               30:16            29:44          40         39
# ...               ...              ...         ...        ...
# 4623            32:47            27:13          33         34
# 4624            30:14            29:46           0         16
# 4625            32:03            27:57          22         24
# 4626            34:05            25:55          24         17
# 4627            26:56            33:04          22         23
#
#      Home_attempts_completed Home_attempts away_attempts_completed  \
# 0                         28            45                      16
# 1                         26            39                      24
# 2                         20            33                      16
# 3                         18            31                      15
# 4                         28            40                      20
# ...                      ...           ...                     ...
# 4623                      27            37                      30
# 4624                      18            28                      20
# 4625                      23            32                      28
# 4626                      26            44                      15
# 4627                      24            39                      18
#
#       away_attempts
# 0              26.0
# 1              30.0
# 2              28.0
# 3              19.0
# 4              29.0
# ...             ...
# 4623           36.0
# 4624           34.0
# 4625           40.0
# 4626           20.0
# 4627           32.0
#
# [4628 rows x 43 columns]

# %%
df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-48-f2d1dcf675e9> in <module>
# ----> 1 df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     448
#     449     else:
# --> 450         assert is_scalar(y), type(y)
#     451         assert isinstance(x, np.ndarray), type(x)
#     452         # mask is only meaningful for x
#
# AssertionError: <class 'list'>

# %%
np.true_divide('passing_yards_away','away_attempts' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-28e49992519b> in <module>
# ----> 1 np.true_divide('passing_yards_away','away_attempts' )
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
np.divide('passing_yards_away','away_attempts' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-912d71d3e4fd> in <module>
# ----> 1 np.divide('passing_yards_away','away_attempts' )
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df['YPPA_Away'] = np.divide('passing_yards_away','away_attempts' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-c95d7fe43534> in <module>
# ----> 1 df['YPPA_Away'] = np.divide('passing_yards_away','away_attempts' )
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df['away_attempts'] = df['away_attempts'].astype(int)

# %%
df['passing_yards_away'] = df['passing_yards_away'].astype(float)

# %%
print(df.dtypes)
# Out:
# date                        object
# away                        object
# home                        object
# first_downs_away             int64
# first_downs_home             int64
# third_downs_away            object
# third_downs_home            object
# fourth_downs_away           object
# fourth_downs_home           object
# passing_yards_away         float64
# passing_yards_home           int64
# rushing_yards_away           int64
# rushing_yards_home           int64
# total_yards_away             int64
# total_yards_home             int64
# comp_att_away               object
# comp_att_home               object
# sacks_away                  object
# sacks_home                  object
# rushing_attempts_away        int64
# rushing_attempts_home        int64
# fumbles_away                 int64
# fumbles_home                 int64
# int_away                     int64
# int_home                     int64
# turnovers_away               int64
# turnovers_home               int64
# penalties_away              object
# penalties_home              object
# redzone_away                object
# redzone_home                object
# drives_away                  int64
# drives_home                  int64
# def_st_td_away               int64
# def_st_td_home               int64
# possession_away             object
# possession_home             object
# score_away                   int64
# score_home                   int64
# Home_attempts_completed     object
# Home_attempts               object
# away_attempts_completed     object
# away_attempts                int64
# dtype: object

# %%
df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     967         try:
# --> 968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     220     if use_numexpr:
# --> 221         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     222     return _evaluate_standard(op, op_str, a, b)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# <ipython-input-55-f2d1dcf675e9> in <module>
# ----> 1 df['YPPA_away'] = df['passing_yards_away']/['away_attempts']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(left, right)
#    1046
#    1047         with np.errstate(all="ignore"):
# -> 1048             result = na_op(lvalues, rvalues)
#    1049         return construct_result(
#    1050             left, result, index=left.index, name=res_name, dtype=None
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#     968             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#     969         except TypeError:
# --> 970             result = masked_arith_op(x, y, op)
#     971
#     972         return missing.dispatch_fill_zeros(op, x, y, result)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in masked_arith_op(x, y, op)
#     448
#     449     else:
# --> 450         assert is_scalar(y), type(y)
#     451         assert isinstance(x, np.ndarray), type(x)
#     452         # mask is only meaningful for x
#
# AssertionError: <class 'list'>

# %%
np.true_divide('passing_yards_away','away_attempts' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-28e49992519b> in <module>
# ----> 1 np.true_divide('passing_yards_away','away_attempts' )
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df['YPPA_Away'] = np.divide('passing_yards_away','away_attempts' )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-c95d7fe43534> in <module>
# ----> 1 df['YPPA_Away'] = np.divide('passing_yards_away','away_attempts' )
#
# TypeError: ufunc 'true_divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df['YPPA_away'] = np.where(df['away_attempts'] < 1, df['away_attempts'], df['passing_yards_away']/df['away_attempts'])

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  def_st_td_home  possession_away  \
# 0                  166.0  ...               0            27:32
# 1                  193.0  ...               0            21:06
# 2                  228.0  ...               0            31:31
# 3                  160.0  ...               0            37:48
# 4                  276.0  ...               0            30:16
# ...                  ...  ...             ...              ...
# 4623               341.0  ...               0            32:47
# 4624               165.0  ...               0            30:14
# 4625               270.0  ...               0            32:03
# 4626               132.0  ...               0            34:05
# 4627               243.0  ...               0            26:56
#
#       possession_home  score_away  score_home Home_attempts_completed  \
# 0               32:28          16          13                      28
# 1               39:08          37          31                      26
# 2               28:29          23          27                      20
# 3               22:12          34           6                      18
# 4               29:44          40          39                      28
# ...               ...         ...         ...                     ...
# 4623            27:13          33          34                      27
# 4624            29:46           0          16                      18
# 4625            27:57          22          24                      23
# 4626            25:55          24          17                      26
# 4627            33:04          22          23                      24
#
#      Home_attempts away_attempts_completed away_attempts  YPPA_away
# 0               45                      16            26   6.384615
# 1               39                      24            30   6.433333
# 2               33                      16            28   8.142857
# 3               31                      15            19   8.421053
# 4               40                      20            29   9.517241
# ...            ...                     ...           ...        ...
# 4623            37                      30            36   9.472222
# 4624            28                      20            34   4.852941
# 4625            32                      28            40   6.750000
# 4626            44                      15            20   6.600000
# 4627            39                      18            32   7.593750
#
# [4628 rows x 44 columns]

# %%
df['YPPA_home'] = np.where(df['Home_attempts'] < 1, df['Home_attempts'], df['passing_yards_home']/df['Home_attempts'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-22d6b335b94e> in <module>
# ----> 1 df['YPPA_home'] = np.where(df['Home_attempts'] < 1, df['Home_attempts'], df['passing_yards_home']/df['Home_attempts'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
df['Home_attempts'] = df['Home_attempts'].astype(int)

# %%
df['passing_yards_home'] = df['passing_yards_home'].astype(float)

# %%
df['YPPA_home'] = np.where(df['Home_attempts'] < 1, df['Home_attempts'], df['passing_yards_home']/df['Home_attempts'])

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  possession_away  possession_home  score_away  \
# 0                  166.0  ...            27:32            32:28          16
# 1                  193.0  ...            21:06            39:08          37
# 2                  228.0  ...            31:31            28:29          23
# 3                  160.0  ...            37:48            22:12          34
# 4                  276.0  ...            30:16            29:44          40
# ...                  ...  ...              ...              ...         ...
# 4623               341.0  ...            32:47            27:13          33
# 4624               165.0  ...            30:14            29:46           0
# 4625               270.0  ...            32:03            27:57          22
# 4626               132.0  ...            34:05            25:55          24
# 4627               243.0  ...            26:56            33:04          22
#
#       score_home  Home_attempts_completed Home_attempts  \
# 0             13                       28            45
# 1             31                       26            39
# 2             27                       20            33
# 3              6                       18            31
# 4             39                       28            40
# ...          ...                      ...           ...
# 4623          34                       27            37
# 4624          16                       18            28
# 4625          24                       23            32
# 4626          17                       26            44
# 4627          23                       24            39
#
#      away_attempts_completed away_attempts YPPA_away  YPPA_home
# 0                         16            26  6.384615   7.066667
# 1                         24            30  6.433333   6.205128
# 2                         16            28  8.142857   8.727273
# 3                         15            19  8.421053   5.387097
# 4                         20            29  9.517241   8.800000
# ...                      ...           ...       ...        ...
# 4623                      30            36  9.472222   9.189189
# 4624                      20            34  4.852941   5.964286
# 4625                      28            40  6.750000  10.187500
# 4626                      15            20  6.600000   7.181818
# 4627                      18            32  7.593750   7.102564
#
# [4628 rows x 45 columns]

# %%
df['YPPA_away'] = np.round('YPPA_away')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-c3416ed55f55> in <module>
# ----> 1 df['YPPA_away'] = np.round('YPPA_away')
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3519     around : equivalent function; see for details.
#    3520     """
# -> 3521     return around(a, decimals=decimals, out=out)
#    3522
#    3523
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3144
#    3145     """
# -> 3146     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3147
#    3148
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# TypeError: ufunc 'rint' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df['YPPA_away'] = np.round_('YPPA_away')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-ee0d558ca80b> in <module>
# ----> 1 df['YPPA_away'] = np.round_('YPPA_away')
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3519     around : equivalent function; see for details.
#    3520     """
# -> 3521     return around(a, decimals=decimals, out=out)
#    3522
#    3523
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3144
#    3145     """
# -> 3146     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3147
#    3148
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# TypeError: ufunc 'rint' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
x= np.round('YPPA_away')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-8588aea86dde> in <module>
# ----> 1 x= np.round('YPPA_away')
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3519     around : equivalent function; see for details.
#    3520     """
# -> 3521     return around(a, decimals=decimals, out=out)
#    3522
#    3523
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3144
#    3145     """
# -> 3146     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3147
#    3148
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# TypeError: ufunc 'rint' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df['YPPA_away'] = np.round_('YPPA_away')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-ee0d558ca80b> in <module>
# ----> 1 df['YPPA_away'] = np.round_('YPPA_away')
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3519     around : equivalent function; see for details.
#    3520     """
# -> 3521     return around(a, decimals=decimals, out=out)
#    3522
#    3523
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3144
#    3145     """
# -> 3146     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3147
#    3148
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# TypeError: ufunc 'rint' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
df['YPPA_away'] = np.round_('YPPA_away', decimals = 1)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-70-e99898e6d6de> in <module>
# ----> 1 df['YPPA_away'] = np.round_('YPPA_away', decimals = 1)
#
# <__array_function__ internals> in round_(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in round_(a, decimals, out)
#    3519     around : equivalent function; see for details.
#    3520     """
# -> 3521     return around(a, decimals=decimals, out=out)
#    3522
#    3523
#
# <__array_function__ internals> in around(*args, **kwargs)
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in around(a, decimals, out)
#    3144
#    3145     """
# -> 3146     return _wrapfunc(a, 'round', decimals=decimals, out=out)
#    3147
#    3148
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     bound = getattr(obj, method, None)
#      57     if bound is None:
# ---> 58         return _wrapit(obj, method, *args, **kwds)
#      59
#      60     try:
#
# ~/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')

# %%
print(df.dtypes)
# Out:
# date                        object
# away                        object
# home                        object
# first_downs_away             int64
# first_downs_home             int64
# third_downs_away            object
# third_downs_home            object
# fourth_downs_away           object
# fourth_downs_home           object
# passing_yards_away         float64
# passing_yards_home         float64
# rushing_yards_away           int64
# rushing_yards_home           int64
# total_yards_away             int64
# total_yards_home             int64
# comp_att_away               object
# comp_att_home               object
# sacks_away                  object
# sacks_home                  object
# rushing_attempts_away        int64
# rushing_attempts_home        int64
# fumbles_away                 int64
# fumbles_home                 int64
# int_away                     int64
# int_home                     int64
# turnovers_away               int64
# turnovers_home               int64
# penalties_away              object
# penalties_home              object
# redzone_away                object
# redzone_home                object
# drives_away                  int64
# drives_home                  int64
# def_st_td_away               int64
# def_st_td_home               int64
# possession_away             object
# possession_home             object
# score_away                   int64
# score_home                   int64
# Home_attempts_completed     object
# Home_attempts                int64
# away_attempts_completed     object
# away_attempts                int64
# YPPA_away                  float64
# YPPA_home                  float64
# dtype: object

# %%
df['YPPA_away'] = df.round_('YPPA_away', decimals = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-be7a20300a57> in <module>
# ----> 1 df['YPPA_away'] = df.round_('YPPA_away', decimals = 1)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'round_'

# %%
df['YPPA_away'] = df.round('YPPA_away', decimals = 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-9f24a08e78a2> in <module>
# ----> 1 df['YPPA_away'] = df.round('YPPA_away', decimals = 1)
#
# TypeError: round() got multiple values for argument 'decimals'

# %%
df['YPPA_away'].round(1)
# Out:
# 0       6.4
# 1       6.4
# 2       8.1
# 3       8.4
# 4       9.5
#        ...
# 4623    9.5
# 4624    4.9
# 4625    6.8
# 4626    6.6
# 4627    7.6
# Name: YPPA_away, Length: 4628, dtype: float64

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  possession_away  possession_home  score_away  \
# 0                  166.0  ...            27:32            32:28          16
# 1                  193.0  ...            21:06            39:08          37
# 2                  228.0  ...            31:31            28:29          23
# 3                  160.0  ...            37:48            22:12          34
# 4                  276.0  ...            30:16            29:44          40
# ...                  ...  ...              ...              ...         ...
# 4623               341.0  ...            32:47            27:13          33
# 4624               165.0  ...            30:14            29:46           0
# 4625               270.0  ...            32:03            27:57          22
# 4626               132.0  ...            34:05            25:55          24
# 4627               243.0  ...            26:56            33:04          22
#
#       score_home  Home_attempts_completed Home_attempts  \
# 0             13                       28            45
# 1             31                       26            39
# 2             27                       20            33
# 3              6                       18            31
# 4             39                       28            40
# ...          ...                      ...           ...
# 4623          34                       27            37
# 4624          16                       18            28
# 4625          24                       23            32
# 4626          17                       26            44
# 4627          23                       24            39
#
#      away_attempts_completed away_attempts YPPA_away  YPPA_home
# 0                         16            26  6.384615   7.066667
# 1                         24            30  6.433333   6.205128
# 2                         16            28  8.142857   8.727273
# 3                         15            19  8.421053   5.387097
# 4                         20            29  9.517241   8.800000
# ...                      ...           ...       ...        ...
# 4623                      30            36  9.472222   9.189189
# 4624                      20            34  4.852941   5.964286
# 4625                      28            40  6.750000  10.187500
# 4626                      15            20  6.600000   7.181818
# 4627                      18            32  7.593750   7.102564
#
# [4628 rows x 45 columns]

# %%
df['YPPA_away'] = df['YPPA_away'].round(1)

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  possession_away  possession_home  score_away  \
# 0                  166.0  ...            27:32            32:28          16
# 1                  193.0  ...            21:06            39:08          37
# 2                  228.0  ...            31:31            28:29          23
# 3                  160.0  ...            37:48            22:12          34
# 4                  276.0  ...            30:16            29:44          40
# ...                  ...  ...              ...              ...         ...
# 4623               341.0  ...            32:47            27:13          33
# 4624               165.0  ...            30:14            29:46           0
# 4625               270.0  ...            32:03            27:57          22
# 4626               132.0  ...            34:05            25:55          24
# 4627               243.0  ...            26:56            33:04          22
#
#       score_home  Home_attempts_completed Home_attempts  \
# 0             13                       28            45
# 1             31                       26            39
# 2             27                       20            33
# 3              6                       18            31
# 4             39                       28            40
# ...          ...                      ...           ...
# 4623          34                       27            37
# 4624          16                       18            28
# 4625          24                       23            32
# 4626          17                       26            44
# 4627          23                       24            39
#
#      away_attempts_completed away_attempts YPPA_away  YPPA_home
# 0                         16            26       6.4   7.066667
# 1                         24            30       6.4   6.205128
# 2                         16            28       8.1   8.727273
# 3                         15            19       8.4   5.387097
# 4                         20            29       9.5   8.800000
# ...                      ...           ...       ...        ...
# 4623                      30            36       9.5   9.189189
# 4624                      20            34       4.9   5.964286
# 4625                      28            40       6.8  10.187500
# 4626                      15            20       6.6   7.181818
# 4627                      18            32       7.6   7.102564
#
# [4628 rows x 45 columns]

# %%
df['YPPA_home'] = df['YPPA_home'].round(1)

# %%
df
# Out:
#             date      away       home  first_downs_away  first_downs_home  \
# 0     2002-09-05     49ers     Giants                13                21
# 1     2002-09-08      Jets      Bills                18                26
# 2     2002-09-08   Vikings      Bears                19                20
# 3     2002-09-08  Chargers    Bengals                27                13
# 4     2002-09-08    Chiefs     Browns                24                24
# ...          ...       ...        ...               ...               ...
# 4623  2019-10-13   Falcons  Cardinals                31                24
# 4624  2019-10-13    Titans    Broncos                12                11
# 4625  2019-10-13   Cowboys       Jets                26                20
# 4626  2019-10-13  Steelers   Chargers                18                23
# 4627  2019-10-14     Lions    Packers                13                22
#
#      third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0                4-12             9-16               0-0               0-1
# 1                 2-8             7-17               0-0               2-2
# 2                5-13             7-13               0-0               0-0
# 3                6-10             4-11               0-0               0-0
# 4                5-11             4-11               0-0               0-0
# ...               ...              ...               ...               ...
# 4623             6-11             7-13               0-0               1-1
# 4624             2-14             2-14               0-2               0-0
# 4625            10-17             2-10               0-1               0-0
# 4626             8-13             7-12               0-0               0-0
# 4627             3-13             4-12               1-1               0-0
#
#       passing_yards_away  ...  possession_away  possession_home  score_away  \
# 0                  166.0  ...            27:32            32:28          16
# 1                  193.0  ...            21:06            39:08          37
# 2                  228.0  ...            31:31            28:29          23
# 3                  160.0  ...            37:48            22:12          34
# 4                  276.0  ...            30:16            29:44          40
# ...                  ...  ...              ...              ...         ...
# 4623               341.0  ...            32:47            27:13          33
# 4624               165.0  ...            30:14            29:46           0
# 4625               270.0  ...            32:03            27:57          22
# 4626               132.0  ...            34:05            25:55          24
# 4627               243.0  ...            26:56            33:04          22
#
#       score_home  Home_attempts_completed Home_attempts  \
# 0             13                       28            45
# 1             31                       26            39
# 2             27                       20            33
# 3              6                       18            31
# 4             39                       28            40
# ...          ...                      ...           ...
# 4623          34                       27            37
# 4624          16                       18            28
# 4625          24                       23            32
# 4626          17                       26            44
# 4627          23                       24            39
#
#      away_attempts_completed away_attempts YPPA_away  YPPA_home
# 0                         16            26       6.4        7.1
# 1                         24            30       6.4        6.2
# 2                         16            28       8.1        8.7
# 3                         15            19       8.4        5.4
# 4                         20            29       9.5        8.8
# ...                      ...           ...       ...        ...
# 4623                      30            36       9.5        9.2
# 4624                      20            34       4.9        6.0
# 4625                      28            40       6.8       10.2
# 4626                      15            20       6.6        7.2
# 4627                      18            32       7.6        7.1
#
# [4628 rows x 45 columns]

# %%
df.to_csv(r'/home/johnd/Documents/NFLdataset.csv')
