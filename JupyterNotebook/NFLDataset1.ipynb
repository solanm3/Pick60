# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pandas.read_csv('NFLdataset.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-62ce67e96b7a> in <module>
# ----> 1 df = pandas.read_csv('NFLdataset.csv')
#
# NameError: name 'pandas' is not defined

# %%
import pandas

# %%
df = pandas.read_csv('NFLdataset.csv')

# %%
import numpy

# %%
df.head()
# Out:
#    Unnamed: 0        date      away     home  first_downs_away  \
# 0           0  2002-09-05     49ers   Giants                13
# 1           1  2002-09-08      Jets    Bills                18
# 2           2  2002-09-08   Vikings    Bears                19
# 3           3  2002-09-08  Chargers  Bengals                27
# 4           4  2002-09-08    Chiefs   Browns                24
#
#    first_downs_home third_downs_away third_downs_home fourth_downs_away  \
# 0                21             4-12             9-16               0-0
# 1                26              2-8             7-17               0-0
# 2                20             5-13             7-13               0-0
# 3                13             6-10             4-11               0-0
# 4                24             5-11             4-11               0-0
#
#   fourth_downs_home  ...  possession_away  possession_home  score_away  \
# 0               0-1  ...            27:32            32:28          16
# ...

# %%
import numpty as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-b1ce91a29230> in <module>
# ----> 1 import numpty as np
#
# ModuleNotFoundError: No module named 'numpty'

# %%
import numpy as np

# %%
import pandas as pd

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'away', 'home', 'first_downs_away',
#        'first_downs_home', 'third_downs_away', 'third_downs_home',
#        'fourth_downs_away', 'fourth_downs_home', 'passing_yards_away',
#        'passing_yards_home', 'rushing_yards_away', 'rushing_yards_home',
#        'total_yards_away', 'total_yards_home', 'comp_att_away',
#        'comp_att_home', 'sacks_away', 'sacks_home', 'rushing_attempts_away',
#        'rushing_attempts_home', 'fumbles_away', 'fumbles_home', 'int_away',
#        'int_home', 'turnovers_away', 'turnovers_home', 'penalties_away',
#        'penalties_home', 'redzone_away', 'redzone_home', 'drives_away',
#        'drives_home', 'def_st_td_away', 'def_st_td_home', 'possession_away',
#        'possession_home', 'score_away', 'score_home',
#        'Home_attempts_completed', 'Home_attempts', 'away_attempts_completed',
#        'away_attempts', 'YPPA_away', 'YPPA_home'],
#       dtype='object')

# %%
df.insert("Average_Yards_Per_Run_Home")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d17e2d5cf851> in <module>
# ----> 1 df.insert("Average_Yards_Per_Run_Home")
#
# TypeError: insert() missing 2 required positional arguments: 'column' and 'value'

# %%
new = df['Average_Yards_Per_Run_Home']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Average_Yards_Per_Run_Home'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-89480fc1b29c> in <module>
# ...

# %%
Average_Yards_Per_Run_Home = []

# %%
df['Average_Yards_Per_Run_Home'] = Average_Yards_Per_Run_Home
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-3d34112a5f32> in <module>
# ----> 1 df['Average_Yards_Per_Run_Home'] = Average_Yards_Per_Run_Home
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3485         else:
#    3486             # set column
# -> 3487             self._set_item(key, value)
#    3488
#    3489     def _setitem_slice(self, key, value):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3562
#    3563         self._ensure_valid_index(value)
# -> 3564         value = self._sanitize_column(key, value)
#    3565         NDFrame._set_item(self, key, value)
#    3566
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3747
#    3748             # turn me into an ndarray
# ...

# %%
df['Average_Yards_Per_Rush_Attempt_Home'] = np.where(df['rushing_attempts_home'] < 1, df['rushing_attempts_home'], df['rushing_yards_home']/df['rushing_attempts_home'])

# %%
df.head()
# Out:
#    Unnamed: 0        date      away     home  first_downs_away  \
# 0           0  2002-09-05     49ers   Giants                13
# 1           1  2002-09-08      Jets    Bills                18
# 2           2  2002-09-08   Vikings    Bears                19
# 3           3  2002-09-08  Chargers  Bengals                27
# 4           4  2002-09-08    Chiefs   Browns                24
#
#    first_downs_home third_downs_away third_downs_home fourth_downs_away  \
# 0                21             4-12             9-16               0-0
# 1                26              2-8             7-17               0-0
# 2                20             5-13             7-13               0-0
# 3                13             6-10             4-11               0-0
# 4                24             5-11             4-11               0-0
#
#   fourth_downs_home  ...  possession_home  score_away  score_home  \
# 0               0-1  ...            32:28          16          13
# ...

# %%
df['Average_Yards_Per_Rush_Attempt_Away'] = np.where(df['rushing_attempts_away'] < 1, df['rushing_attempts_away'], df['rushing_yards_away']/df['rushing_attempts_away'])

# %%
df.head()
# Out:
#    Unnamed: 0        date      away     home  first_downs_away  \
# 0           0  2002-09-05     49ers   Giants                13
# 1           1  2002-09-08      Jets    Bills                18
# 2           2  2002-09-08   Vikings    Bears                19
# 3           3  2002-09-08  Chargers  Bengals                27
# 4           4  2002-09-08    Chiefs   Browns                24
#
#    first_downs_home third_downs_away third_downs_home fourth_downs_away  \
# 0                21             4-12             9-16               0-0
# 1                26              2-8             7-17               0-0
# 2                20             5-13             7-13               0-0
# 3                13             6-10             4-11               0-0
# 4                24             5-11             4-11               0-0
#
#   fourth_downs_home  ...  score_away  score_home  Home_attempts_completed  \
# 0               0-1  ...          16          13                       28
# ...

# %%
df['Average_Yards_Per_Rush_Attempt_Home'] = df['Average_Yards_Per_Rush_Attempt_Home'].round(1)

# %%
df['Average_Yards_Per_Rush_Attempt_Away'] = df['Average_Yards_Per_Rush_Attempt_Away'].round(1)

# %%
df.head()
# Out:
#    Unnamed: 0        date      away     home  first_downs_away  \
# 0           0  2002-09-05     49ers   Giants                13
# 1           1  2002-09-08      Jets    Bills                18
# 2           2  2002-09-08   Vikings    Bears                19
# 3           3  2002-09-08  Chargers  Bengals                27
# 4           4  2002-09-08    Chiefs   Browns                24
#
#    first_downs_home third_downs_away third_downs_home fourth_downs_away  \
# 0                21             4-12             9-16               0-0
# 1                26              2-8             7-17               0-0
# 2                20             5-13             7-13               0-0
# 3                13             6-10             4-11               0-0
# 4                24             5-11             4-11               0-0
#
#   fourth_downs_home  ...  score_away  score_home  Home_attempts_completed  \
# 0               0-1  ...          16          13                       28
# ...

# %%
df['Pts_Per_Drive_home'] = np.where(df['drives_home'] < 1, df['drives_home'], df['score_home']/df['drives_home'])

# %%
df.head()
# Out:
#    Unnamed: 0        date      away     home  first_downs_away  \
# 0           0  2002-09-05     49ers   Giants                13
# 1           1  2002-09-08      Jets    Bills                18
# 2           2  2002-09-08   Vikings    Bears                19
# 3           3  2002-09-08  Chargers  Bengals                27
# 4           4  2002-09-08    Chiefs   Browns                24
#
#    first_downs_home third_downs_away third_downs_home fourth_downs_away  \
# 0                21             4-12             9-16               0-0
# 1                26              2-8             7-17               0-0
# 2                20             5-13             7-13               0-0
# 3                13             6-10             4-11               0-0
# 4                24             5-11             4-11               0-0
#
#   fourth_downs_home  ...  score_home  Home_attempts_completed  Home_attempts  \
# ...

# %%
df['Pts_Per_Drive_away'] = np.where(df['drives_away'] < 1, df['drives_away'], df['score_away']/df['drives_away'])

# %%
df['Pts_Per_Drive_away'] = df['Pts_Per_Drive_away'].round(2)

# %%
df['Pts_Per_Drive_home'] = df['Pts_Per_Drive_home'].round(2)

# %%
df.head()
# Out:
#    Unnamed: 0        date      away     home  first_downs_away  \
# 0           0  2002-09-05     49ers   Giants                13
# 1           1  2002-09-08      Jets    Bills                18
# 2           2  2002-09-08   Vikings    Bears                19
# 3           3  2002-09-08  Chargers  Bengals                27
# 4           4  2002-09-08    Chiefs   Browns                24
#
#    first_downs_home third_downs_away third_downs_home fourth_downs_away  \
# 0                21             4-12             9-16               0-0
# 1                26              2-8             7-17               0-0
# 2                20             5-13             7-13               0-0
# 3                13             6-10             4-11               0-0
# 4                24             5-11             4-11               0-0
#
#   fourth_downs_home  ...  Home_attempts_completed  Home_attempts  \
# 0               0-1  ...                       28             45
# ...

# %%
df = pd.concat(['score_home', 'score_away'], axis = 1)
df['Home_Result'] = np.where(df['score_home'] > df['score_away'], 'W', 'L')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-83a638d3c9c2> in <module>
# ----> 1 df = pd.concat(['score_home', 'score_away'], axis = 1)
#       2 df['Home_Result'] = np.where(df['score_home'] > df['score_away'], 'W', 'L')
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253         verify_integrity=verify_integrity,
#     254         copy=copy,
# --> 255         sort=sort,
#     256     )
#     257
#
# ~/.local/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     330                     " only Series and DataFrame objs are valid".format(type(obj))
#     331                 )
# ...

# %%
df['Home_Result'] = np.where(df.score_home > df.score_away, 'Win', 'Loss')

# %%
df.head()
# Out:
#    Unnamed: 0        date      away     home  first_downs_away  \
# 0           0  2002-09-05     49ers   Giants                13
# 1           1  2002-09-08      Jets    Bills                18
# 2           2  2002-09-08   Vikings    Bears                19
# 3           3  2002-09-08  Chargers  Bengals                27
# 4           4  2002-09-08    Chiefs   Browns                24
#
#    first_downs_home third_downs_away third_downs_home fourth_downs_away  \
# 0                21             4-12             9-16               0-0
# 1                26              2-8             7-17               0-0
# 2                20             5-13             7-13               0-0
# 3                13             6-10             4-11               0-0
# 4                24             5-11             4-11               0-0
#
#   fourth_downs_home  ...  Home_attempts  away_attempts_completed  \
# 0               0-1  ...             45                       16
# ...

# %%
df.to_csv(r'/home/johnd/Documents/NFLdataset1.csv')

# %%
df['Home_Result'] = np.where(df.score_home > df.score_away, df.score_home == df.score_away, 'Win', 'Tie', 'Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fe4f69c0cb9c> in <module>
# ----> 1 df['Home_Result'] = np.where(df.score_home > df.score_away, df.score_home == df.score_away, 'Win', 'Tie', 'Loss')
#
# NameError: name 'np' is not defined

# %%
import numpy

# %%
import numpy as np

# %%
df['Home_Result'] = np.where(df.score_home > df.score_away, df.score_home == df.score_away, 'Win', 'Tie', 'Loss')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fe4f69c0cb9c> in <module>
# ----> 1 df['Home_Result'] = np.where(df.score_home > df.score_away, df.score_home == df.score_away, 'Win', 'Tie', 'Loss')
#
# NameError: name 'df' is not defined
